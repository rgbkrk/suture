# %% [markdown]
# Automerge. Suture self.

# %%
import suture

repo = suture.Repo()
await repo.connect_websocket("wss://sync.automerge.org")

# %%
doc = await repo.create()

# %%
await doc.set_string("title", "Suture self")

# %%
await doc.dump()
# Out:
# b"\x85oJ\x83d\xa3\xca\x9d\x00\x83\x01\x01\x10\x18\xa6bVmk\n}\x80n\x8a\xc1O2AR\x01IR\xd2cy\x0cN'Rg\x07\xe1\n\x994\r\xa0W\x00P\xdb\x0f\x1a\xeb\xea\xb3F\\<*\xd2q\x07\x01\x02\x03\x02\x13\x03#\x02@\x03C\x02V\x02\x08\x15\x07!\x02#\x024\x01B\x02V\x03W\x0b\x80\x01\x02\x02\x00\x02\x01~\x00\x01\x02\x00~\x00\x01\x7f\x00\x02\x07\x7f\x05title\x7f\x00\x7f\x01\x01\x7f\x01\x7f\xb6\x01Suture self\x7f\x00\x01"
